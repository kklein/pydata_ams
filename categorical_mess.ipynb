# %% [markdown]
# # Load, explore and process data

# %%
import pandas as pd

# %%
df = pd.read_csv("~/Code/pydata_ams/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df["Sex"] = df["Sex"].map({"male": 0, "female": 1})

# %%
df["Pclass"] = df["Pclass"].astype("category")
df["Embarked"] = df["Embarked"].astype("category")

# %%
df["Embarked"]
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: category
# Categories (3, object): ['C', 'Q', 'S']

# %%
df["Pclass"]
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: category
# Categories (3, int64): [1, 2, 3]

# %%
X = df[["Embarked", "Pclass", "Sex"]]
y = df["Survived"]

# %% [markdown]
# # Train a classification model with `lightgbm`

# %%
import lightgbm as lgbm

# %%
clf = lgbm.LGBMClassifier(verbosity=-1, max_depth=6)
clf.fit(X, y)
# Out:
# LGBMClassifier(max_depth=6, verbosity=-1)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(15, 10))
lgbm.plot_tree(clf, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# # Train a CATE model with `causalml`

# %%
import numpy as np
rng = np.random.default_rng()
treatment = pd.Series(rng.binomial(n=1, p=.5, size=len(X)))

# %%
treatment
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 886    0
# 887    0
# 888    0
# 889    0
# 890    0
# Length: 891, dtype: int64

# %%
# %%capture
from causalml.inference.meta import BaseRClassifier

# %%
model = BaseRClassifier(
    outcome_learner=lgbm.LGBMClassifier(verbosity=-1),
    effect_learner=lgbm.LGBMRegressor(verbosity=-1),
    propensity_learner=lgbm.LGBMClassifier(verbosity=-1),
)

# %%
model.fit(X=X, treatment=treatment, y=y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 model.fit(X=X, treatment=treatment, y=y)
#
# File ~/micromamba/envs/ams/lib/python3.10/site-packages/causalml/inference/meta/rlearner.py:453, in BaseRClassifier.fit(self, X, treatment, y, p, sample_weight, verbose)
#     450 self.t_groups.sort()
#     452 if p is None:
# --> 453     self._set_propensity_models(X=X, treatment=treatment, y=y)
#     454     p = self.propensity
#     455 else:
#
# File ~/micromamba/envs/ams/lib/python3.10/site-packages/causalml/inference/meta/base.py:115, in BaseLearner._set_propensity_models(self, X, treatment, y)
#     113     w = (treatment == group).astype(int)
#     114     propensity_model = self.model_p if hasattr(self, "model_p") else None
# --> 115     p[group], p_model[group] = compute_propensity_score(
#     116         X=X_filt,
#     117         treatment=w_filt,
#     118         p_model=propensity_model,
#     119         X_pred=X,
#     120         treatment_pred=w,
#     121     )
#     122 self.propensity_model = p_model
#     123 self.propensity = p
#
# File ~/micromamba/envs/ams/lib/python3.10/site-packages/causalml/propensity.py:220, in compute_propensity_score(X, treatment, p_model, X_pred, treatment_pred, calibrate_p)
#     217 if p_model is None:
#     218     p_model = ElasticNetPropensityModel()
# --> 220 p_model.fit(X, treatment)
#     222 if X_pred is None:
#     223     p = p_model.predict(X)
#
# File ~/micromamba/envs/ams/lib/python3.10/site-packages/lightgbm/sklearn.py:1142, in LGBMClassifier.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1139         else:
#    1140             valid_sets.append((valid_x, self._le.transform(valid_y)))
# -> 1142 super().fit(
#    1143     X,
#    1144     _y,
#    1145     sample_weight=sample_weight,
#    1146     init_score=init_score,
#    1147     eval_set=valid_sets,
#    1148     eval_names=eval_names,
#    1149     eval_sample_weight=eval_sample_weight,
#    1150     eval_class_weight=eval_class_weight,
#    1151     eval_init_score=eval_init_score,
#    1152     eval_metric=eval_metric,
#    1153     feature_name=feature_name,
#    1154     categorical_feature=categorical_feature,
#    1155     callbacks=callbacks,
#    1156     init_model=init_model
#    1157 )
#    1158 return self
#
# File ~/micromamba/envs/ams/lib/python3.10/site-packages/lightgbm/sklearn.py:770, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#     767 params['metric'] = [metric for metric in params['metric'] if metric is not None]
#     769 if not isinstance(X, (pd_DataFrame, dt_DataTable)):
# --> 770     _X, _y = _LGBMCheckXY(X, y, accept_sparse=True, force_all_finite=False, ensure_min_samples=2)
#     771     if sample_weight is not None:
#     772         sample_weight = _LGBMCheckSampleWeight(sample_weight, _X)
#
# File ~/micromamba/envs/ams/lib/python3.10/site-packages/sklearn/utils/validation.py:964, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     961 if y is None:
#     962     raise ValueError("y cannot be None")
# --> 964 X = check_array(
#     965     X,
#     966     accept_sparse=accept_sparse,
#     967     accept_large_sparse=accept_large_sparse,
#     968     dtype=dtype,
#     969     order=order,
#     970     copy=copy,
#     971     force_all_finite=force_all_finite,
#     972     ensure_2d=ensure_2d,
#     973     allow_nd=allow_nd,
#     974     ensure_min_samples=ensure_min_samples,
#     975     ensure_min_features=ensure_min_features,
#     976     estimator=estimator,
#     977 )
#     979 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#     981 check_consistent_length(X, y)
#
# File ~/micromamba/envs/ams/lib/python3.10/site-packages/sklearn/utils/validation.py:746, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744         array = array.astype(dtype, casting="unsafe", copy=False)
#     745     else:
# --> 746         array = np.asarray(array, order=order, dtype=dtype)
#     747 except ComplexWarning as complex_warning:
#     748     raise ValueError(
#     749         "Complex data not supported\n{}\n".format(array)
#     750     ) from complex_warning
#
# ValueError: could not convert string to float: 'S'

# %%
X_reduced = X[["Pclass", "Sex"]]
model.fit(X=X_reduced, treatment=treatment, y=y)

# %%
fig, ax = plt.subplots(figsize=(15, 10))
lgbm.plot_tree(model.models_tau[1], ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# # Train a CATE model with `econml`

# %%
from econml.dr import DRLearner

# %%
est = DRLearner()
est.fit(y, treatment, X=X_reduced, W=None)
# Out:
# Not all column names are strings. Coercing to strings for now.
